# %%
import json
import pprint
from collections import defaultdict
from pymatgen.core.structure import *
from matminer.data_retrieval.retrieve_MP import MPDataRetrieval

f_MO = open('store_MO.json', 'r')
MO_0 = json.load(f_MO)
f_BM = open('store_BM.json', 'r')
BM_0 = json.load(f_BM)
f_MO = open('store_TM.json', 'r')
TM_0 = json.load(f_MO)
# Out:
# /opt/miniconda3/envs/py3/lib/python3.8/site-packages/pymatgen/ext/matproj.py:454: FutureWarning: __init__ is deprecated
# MaterialsProjectCompatibility will be updated with new correction classes as well as new values of corrections and uncertainties in 2020
#   def get_pourbaix_entries(self, chemsys, solid_compat=MaterialsProjectCompatibility()):

# %%
def full_list(list_0):
    list_all = defaultdict(dict)
    count = 0
    for i in list_0.values():
#     print (len(i))
        for j in list(i.keys()):
#           print (i[j]['composition'])
            list_all[count]['mat_id'] = j
            list_all[count]['composition'] = i[j]['composition']
            list_all[count]['pbxenergy'] = i[j]['energy']
            count += 1
    return list_all

### filter 1: PBX
### filter 2: ehull
### filter 3: cost
def pbxfilter(list_in, energy=0.2):
    list_out = defaultdict(dict)
    count = 0
    for i in range(len(list_in)):
        if list_in[i]['pbxenergy'] < energy:
            list_out[count] = list_in[i]
            count += 1
    return list_out

from pymatgen.analysis.cost import CostAnalyzer, CostDBCSV
costdb_path = "/Users/duowang/Documents/GitHub/nitrate/datasets/costdb_elements_2021.csv"
costdb = CostDBCSV(costdb_path)
costanalyzer = CostAnalyzer(costdb)

def ehullfilter(list_in, energy_barrier=0.1):
    mpdr = MPDataRetrieval(api_key="TUvMnIDcCmqNEiG0")
    list_out = defaultdict(dict)
    count = 0
    mpidlist = [];
    for i in range(len(list_in)):
        mpidlist.append(list_in[i].get('mat_id'))
#    print (mpidlist)
    temp_data = mpdr.get_dataframe({"material_id": {"$in": mpidlist}}, properties=["material_id",'pretty_formula', "e_above_hull", 'formation_energy_per_atom'])
#     print (temp_data)
    temp_data.to_json('temp_data.json')
    temp_file = open('temp_data.json', 'r')
    temp_data = json.load(temp_file)
#     print (list(temp_data.values())[2])
    dict_idtocom = list(temp_data.values())[0]
    dict_idtoene = list(temp_data.values())[1]
    dict_idtoforene = list(temp_data.values())[2]
    for i in range(len(dict_idtocom)):
        temp_matid = list(dict_idtoene.keys())[i]
        temp_comp = list(dict_idtocom.values())[i]
        temp_energy = list(dict_idtoene.values())[i]
        temp_forene = list(dict_idtoforene.values())[i]
        if temp_energy <= energy_barrier:
            list_out[count]['mat_id'] = temp_matid
            list_out[count]['composition'] = temp_comp
            list_out[count]['ehull'] = temp_energy
            list_out[count]['formation_ene'] = temp_forene
            count += 1      
    return (list_out)

def costfilter(list_in, cost=3000):
    list_out = defaultdict(dict)
    count = 0
    for i in range(len(list_in)):
        comp = Composition(list_in[i]['composition']).reduced_formula
        temp_cost = costanalyzer.get_cost_per_kg(comp)
        if temp_cost < cost:
            list_out[count] = list_in[i]
            list_out[count]['unitprice'] = temp_cost
            count += 1
    return list_out

def rmDupDict(list_in):
    list_out = defaultdict(dict)
    seen = []
    count = 0
    for i in range(len(list_in)):
        comp = Composition(list_in[i]['composition']).reduced_formula
        if comp not in seen:
            list_out[count] = list_in[i]
            seen.append(comp)
            count += 1
        if comp in seen:
            if list_in[i]['formation_ene'] < list_out[seen.index(comp)]['formation_ene']:
                list_out[seen.index(comp)] = list_in[i]
    return list_out


def get_compounds(dict_in):
    compound_list = [];
    for i in range(len(dict_in)):
        compound_list.append(dict_in[i].get('composition'))
    return compound_list

def rmDup(list_in):
    list_out = []
    for i in list_in:
        if i not in list_out:
            list_out.append(i)
    return list_out

def includeElement(dict_in, ele_list=['Ni']):
    dict_out = defaultdict(dict)
    count = 0
    for i in range(len(dict_in)):
        comp = Composition(dict_in[i]['composition']).reduced_formula
        tag = 0
        for j in ele_list:
            if j in comp:
                tag = 1
        if tag == 1:
            dict_out[count] = dict_in[i]
            count += 1
    return dict_out

def notincludeElement(dict_in, ele_list=['As', 'Be', 'Cd', 'Cr', 'Pb', 'Hg']):
    dict_out = defaultdict(dict)
    count = 0
    for i in range(len(dict_in)):
        comp = Composition(dict_in[i]['composition']).reduced_formula
        tag = 0
        for j in ele_list:
            if j in comp:
                tag = 1
        if tag == 0:
            dict_out[count] = dict_in[i]
            count += 1
    return dict_out
    
def get_pairs(list_in):
    pair_list = []
    for item in list_in:
        comp = Composition(item).as_dict()
        p = tuple([c[0] for c in sorted(list(comp.items()), reverse=True, key=lambda c: c[1])])
        if p not in pair_list:
            pair_list.append(p)
    return sorted(pair_list, key = lambda x: x[0])

def rmDupPair(plist_in):
    plist_out, seen = [], set()
    for item in plist_in:
        t1 = tuple(item)
        if t1 not in seen and tuple(reversed(item)) not in seen:
            seen.add(t1)
            plist_out.append(item)
    return sorted(plist_out, key = lambda x: x[0])
    
def tuple3to2(tlist3):
    t1 = [x[:2] for x in tlist3]
    t2 = [x[1:3] for x in tlist3]
    t3 = [x[0:3:2] for x in tlist3]
    t_all = t1 + t2 + t3
    return t_all

def printTable(plist_in):
    out_list = []
    for i in plist_in:
        if i[0] not in out_list:
            out_list.append(i[0])
            print (i[0],  end =": ")
            seen = []
            for j in plist_in:
                if (j[0] == i[0]):
                    if j[1] not in seen:
                        seen.append(j[1])
                        print (j[1], end =" ")   
            print ('\n')
        
def getMOElements(plist_in):
    colA = []
    for i in MO_pairs:
        if i[0] != 'O' and i[0] not in colA:
            colA.append(i[0])
        elif i[0] not in colA:
            colA.append(i[1])
    return colA
# Out:
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""September"""," year = ""2013"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""August"""," year = ""2019"""," url = ""http://en.wikipedia.org/wiki/Prices_of_elements_and_their_compounds""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""September"""," year = ""2013"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# /opt/miniconda3/envs/py3/lib/python3.8/site-packages/pymatgen/core/periodic_table.py:438: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn("No electronegativity for %s. Setting to NaN. "
# <INPUT>: @misc{wolfram_alpha," title = ""Wolfram Alpha"""," month = ""June"""," year = ""2020"""," url = ""http://www.wolframalpha.org""}"
# <INPUT>:                    ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{wikipedia," title = ""Wikipedia"""," month = ""June"""," year = ""2020"""," url = ""https://en.wikipedia.org/wiki/Hydrogen_economy#Costs""}"
# <INPUT>:                ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# /opt/miniconda3/envs/py3/lib/python3.8/site-packages/pymatgen/core/periodic_table.py:438: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn("No electronegativity for %s. Setting to NaN. "
# <INPUT>: @misc{internet_search," title = ""Aqua-Calc"""," month = ""June"""," year = ""2020"""," url = ""https://www.aqua-calc.com/calculate/materials-price/substance/argon""}"
# <INPUT>:                      ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# /opt/miniconda3/envs/py3/lib/python3.8/site-packages/pymatgen/core/periodic_table.py:438: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn("No electronegativity for %s. Setting to NaN. "
# <INPUT>: @misc{internet_search," title = ""Pomona College"""," month = ""June"""," year = ""2020"""," url = ""http://www.chemistry.pomona.edu/chemistry/periodic_table/elements/neptunium/the%20facts.htm""}"
# <INPUT>:                      ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{internet_search," title = ""Chemicool"""," month = ""June"""," year = ""2020"""," url = ""https://www.chemicool.com/elements/krypton.html""}"
# <INPUT>:                      ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected
# <INPUT>: @misc{internet_search," title = ""Radiochemistry.org"""," month = ""June"""," year = ""2020"""," url = ""https://www.radiochemistry.org/periodictable/elements/43.html""}"
# <INPUT>:                      ^^^
# <INPUT>: WARNING: syntax error in line 1: '}' expected

# %%
MO_all = full_list(MO_0)
BM_all = full_list(BM_0)
TM_all = full_list(TM_0)
print (len(MO_all),len(BM_all),len(TM_all))
MO_filter1 = pbxfilter(MO_all)
BM_filter1 = pbxfilter(BM_all)
TM_filter1 = pbxfilter(TM_all)
print (len(MO_filter1),len(BM_filter1),len(TM_filter1))
MO_filter2 = ehullfilter(MO_filter1)
BM_filter2 = ehullfilter(BM_filter1)
TM_filter2 = ehullfilter(TM_filter1)
print (len(MO_filter2),len(BM_filter2),len(TM_filter2))
MO_filter3 = costfilter(MO_filter2, cost=3000)
BM_filter3 = costfilter(BM_filter2, cost=3000)
TM_filter3 = costfilter(TM_filter2, cost=3000)
print (len(MO_filter3),len(BM_filter3),len(TM_filter3))
# with open('filtered_MO500.json', 'w') as op_MO:
#     json.dump(MO_filter3, op_MO)
# with open('filtered_BM500.json', 'w') as op_BM:
#     json.dump(BM_filter3, op_BM)
# with open('filtered_TM500.json', 'w') as op_TM:
#     json.dump(TM_filter3, op_TM)
# Out:
# 1617 5589 6832
# 188 1549 765
#   0%|          | 0/1549 [00:00<?, ?it/s]
#   0%|          | 0/765 [00:00<?, ?it/s]
# 144 1300 707
# 144 586 336

# %%
MO_noDup = rmDupDict(MO_filter3)
print (len(MO_noDup))

BM_noDup = rmDupDict(BM_filter3)
print (len(BM_noDup))

TM_noDup = rmDupDict(TM_filter3)
print (len(TM_noDup))

# with open('filtered_MO.json', 'w') as op_MO:
#     json.dump(MO_noDup, op_MO)
# with open('filtered_BM.json', 'w') as op_BM:
#     json.dump(BM_noDup, op_BM)
# with open('filtered_TM.json', 'w') as op_TM:
#     json.dump(TM_noDup, op_TM)

BM_noDup
# Out:
# 37
# 426
# 318
# defaultdict(dict,
#             {0: {'mat_id': 'mp-23313',
#               'composition': 'InBi',
#               'ehull': 0.0,
#               'formation_ene': -0.0029619175,
#               'unitprice': 271.65473987184316},
#              1: {'mat_id': 'mp-20012',
#               'composition': 'InSb',
#               'ehull': 0.0,
#               'formation_ene': -0.1027004875,
#               'unitprice': 356.8097781324518},
#              2: {'mat_id': 'mp-1007852',
#               'composition': 'FeCo3',
#               'ehull': 0.0450887275,
#               'formation_ene': 0.0109458913,
#               'unitprice': 39.731189738230604},
#              3: {'mat_id': 'mp-1007923',
#               'composition': 'CrNi3',
#               'ehull': 0.00026945,
#               'formation_ene': -0.0137269775,
#               'unitprice': 16.45713892743499},
#              4: {'mat_id': 'mp-2157',
#               'composition': 'Co3W',
#               'ehull': 0.0,
#               'formation_ene': -0.07685174,
#               'unitprice': 43.592040545568274},
#              5: {'mat_id': 'mp-1139',
#               'composition': 'Co3Mo',
#               'ehull': 0.0,
#               'formation_ene': -0.0443795912,
#               'unitprice': 48.364664713887855},
#              6: {'mat_id': 'mp-1087479',
#               'composition': 'CrCo3',
#               'ehull': 0.0241693925,
#               'formation_ene': 0.0241693925,
#               'unitprice': 42.484309752856205},
#              7: {'mat_id': 'mp-1183837',
#               'composition': 'Co3Ni',
#               'ehull': 0.0,
#               'formation_ene': -0.025867125,
#               'unitprice': 43.82170202101221},
#              8: {'mat_id': 'mp-1009018',
#               'composition': 'InAg',
#               'ehull': 0.0743671985,
#               'formation_ene': 0.0503278633,
#               'unitprice': 785.6656852714061},
#              9: {'mat_id': 'mp-1016106',
#               'composition': 'HfZn16',
#               'ehull': 0.0,
#               'formation_ene': -0.0727783626,
#               'unitprice': 133.65167753538438},
#              10: {'mat_id': 'mp-1016109',
#               'composition': 'ZrZn16',
#               'ehull': 0.0,
#               'formation_ene': -0.0934958647,
#               'unitprice': 5.599483495652922},
#              11: {'mat_id': 'mp-542614',
#               'composition': 'VCo3',
#               'ehull': 0.0,
#               'formation_ene': -0.1728721983,
#               'unitprice': 123.29711352546214},
#              12: {'mat_id': 'mp-977426',
#               'composition': 'NbCo3',
#               'ehull': 0.0,
#               'formation_ene': -0.15932919,
#               'unitprice': 48.79219174131694},
#              13: {'mat_id': 'mp-1018053',
#               'composition': 'InCu',
#               'ehull': 0.0652829771,
#               'formation_ene': 0.06061678,
#               'unitprice': 466.8976905220912},
#              14: {'mat_id': 'mp-1156',
#               'composition': 'GaSb',
#               'ehull': 0.0,
#               'formation_ene': -0.1565779475,
#               'unitprice': 259.6303920583509},
#              15: {'mat_id': 'mp-1018067',
#               'composition': 'CrFe3',
#               'ehull': 0.0647514125,
#               'formation_ene': 0.0647514125,
#               'unitprice': 2.3874136723680612},
#              16: {'mat_id': 'mp-1018126',
#               'composition': 'GaBi',
#               'ehull': 0.025325715,
#               'formation_ene': 0.025325715,
#               'unitprice': 191.10937575361135},
#              17: {'mat_id': 'mp-13688',
#               'composition': 'Ge2Mo',
#               'ehull': 0.0,
#               'formation_ene': -0.1698876775,
#               'unitprice': 889.6956405015881},
#              18: {'mat_id': 'mp-1021668',
#               'composition': 'In3Sb',
#               'ehull': 0.091557995,
#               'formation_ene': 0.0402077512,
#               'unitprice': 535.7151401166228},
#              19: {'mat_id': 'mp-672371',
#               'composition': 'Ni3Sb',
#               'ehull': 0.0007849825,
#               'formation_ene': -0.14831357,
#               'unitprice': 16.806953475449387},
#              20: {'mat_id': 'mp-1038778',
#               'composition': 'Sn3Bi',
#               'ehull': 0.07632882,
#               'formation_ene': 0.07632882,
#               'unitprice': 30.003647001009604},
#              21: {'mat_id': 'mp-1046',
#               'composition': 'NbSn2',
#               'ehull': 0.0,
#               'formation_ene': -0.1506267183,
#               'unitprice': 35.43647301503501},
#              22: {'mat_id': 'mp-10598',
#               'composition': 'CuSn',
#               'ehull': 0.0,
#               'formation_ene': -0.031949745,
#               'unitprice': 24.65884471808003},
#              23: {'mat_id': 'mp-10635',
#               'composition': 'SnSb',
#               'ehull': 0.0034544275,
#               'formation_ene': 0.0034544275,
#               'unitprice': 23.411762056286857},
#              24: {'mat_id': 'mp-21237',
#               'composition': 'CoGe',
#               'ehull': 0.0,
#               'formation_ene': -0.220180145,
#               'unitprice': 823.9033648602385},
#              25: {'mat_id': 'mp-1069288',
#               'composition': 'MnGa4',
#               'ehull': 0.0,
#               'formation_ene': -0.1751583679,
#               'unitprice': 575.1673200813427},
#              26: {'mat_id': 'mp-1070544',
#               'composition': 'CrGa4',
#               'ehull': 0.0,
#               'formation_ene': -0.156332718,
#               'unitprice': 581.4162652346338},
#              27: {'mat_id': 'mp-1072',
#               'composition': 'Nb5Ga13',
#               'ehull': 0.0704805056,
#               'formation_ene': -0.242315935,
#               'unitprice': 469.24248964181794},
#              28: {'mat_id': 'mp-1191285',
#               'composition': 'NbNi2',
#               'ehull': 0.0785574362,
#               'formation_ene': -0.1844902825,
#               'unitprice': 29.028814707655094},
#              29: {'mat_id': 'mp-1077536',
#               'composition': 'ZnSb2',
#               'ehull': 0.0978262971,
#               'formation_ene': 0.079067145,
#               'unitprice': 11.896134095031632},
#              30: {'mat_id': 'mp-1192350',
#               'composition': 'NbFe2',
#               'ehull': 0.0,
#               'formation_ene': -0.1298251225,
#               'unitprice': 19.314355510591145},
#              31: {'mat_id': 'mp-19870',
#               'composition': 'GaFe3',
#               'ehull': 0.0,
#               'formation_ene': -0.135862275,
#               'unitprice': 202.3497129824748},
#              32: {'mat_id': 'mp-1418',
#               'composition': 'FeNi3',
#               'ehull': 0.0,
#               'formation_ene': -0.0901765575,
#               'unitprice': 14.127411560733117},
#              33: {'mat_id': 'mp-1079399',
#               'composition': 'V3Fe',
#               'ehull': 0.0,
#               'formation_ene': -0.1712836937,
#               'unitprice': 271.035526210347},
#              34: {'mat_id': 'mp-1080001',
#               'composition': 'ZrGa3',
#               'ehull': 0.0,
#               'formation_ene': -0.4890109538,
#               'unitprice': 490.04232448638294},
#              35: {'mat_id': 'mp-20112',
#               'composition': 'Ni3Sn',
#               'ehull': 0.0,
#               'formation_ene': -0.1897594888,
#               'unitprice': 24.26634286847881},
#              36: {'mat_id': 'mp-1080603',
#               'composition': 'Fe7Co',
#               'ehull': 0.0012518138,
#               'formation_ene': -0.0228864144,
#               'unitprice': 7.023777490987388},
#              37: {'mat_id': 'mp-1084800',
#               'composition': 'VGe2',
#               'ehull': 0.0194972343,
#               'formation_ene': -0.1727200456,
#               'unitprice': 1169.6029345954446},
#              38: {'mat_id': 'mp-1084832',
#               'composition': 'Fe5Co3',
#               'ehull': 0.050809125,
#               'formation_ene': 0.4785274644,
#               'unitprice': 20.37253560442781},
#              39: {'mat_id': 'mp-1093999',
#               'composition': 'Zn2Ag',
#               'ehull': 0.0067156123,
#               'formation_ene': -0.0438287353,
#               'unitprice': 388.2523779927983},
#              40: {'mat_id': 'mp-7851',
#               'composition': 'TaCo3',
#               'ehull': 0.0,
#               'formation_ene': -0.2387066696,
#               'unitprice': 102.58451893057277},
#              41: {'mat_id': 'mp-1095578',
#               'composition': 'Ga5Ni',
#               'ehull': 0.0058397333,
#               'formation_ene': -0.1714683092,
#               'unitprice': 591.5835272996624},
#              42: {'mat_id': 'mp-548',
#               'composition': 'NbCr2',
#               'ehull': 0.0,
#               'formation_ene': -0.0270121817,
#               'unitprice': 24.914392101761226},
#              43: {'mat_id': 'mp-1095682',
#               'composition': 'Fe2Mo',
#               'ehull': 0.0395560517,
#               'formation_ene': 0.0395560517,
#               'unitprice': 19.18345443420026},
#              44: {'mat_id': 'mp-1097859',
#               'composition': 'Mn3Ge5',
#               'ehull': 0.0,
#               'formation_ene': -0.0666527183,
#               'unitprice': 998.0258107955766},
#              45: {'mat_id': 'mp-1099',
#               'composition': 'NiGe',
#               'ehull': 0.0,
#               'formation_ene': -0.3078886263,
#               'unitprice': 810.263677178934},
#              46: {'mat_id': 'mp-1101810',
#               'composition': 'Ge2W',
#               'ehull': 0.0320404792,
#               'formation_ene': 0.0320404792,
#               'unitprice': 659.7667696606711},
#              47: {'mat_id': 'mp-1103522',
#               'composition': 'Ga5W2',
#               'ehull': 0.0581868714,
#               'formation_ene': 0.0581868714,
#               'unitprice': 352.9939535606559},
#              48: {'mat_id': 'mp-1105040',
#               'composition': 'Ta6Zn7',
#               'ehull': 0.0,
#               'formation_ene': -0.0853319781,
#               'unitprice': 107.64652616422927},
#              49: {'mat_id': 'mp-1105044',
#               'composition': 'Nb6Ni7',
#               'ehull': 0.0062346508,
#               'formation_ene': -0.2109558677,
#               'unitprice': 32.20740018214593},
#              50: {'mat_id': 'mp-570293',
#               'composition': 'Nb5Ga3',
#               'ehull': 0.0082068884,
#               'formation_ene': -0.3320893263,
#               'unitprice': 242.78077810410824},
#              51: {'mat_id': 'mp-1106023',
#               'composition': 'NiSb3',
#               'ehull': 0.0069278969,
#               'formation_ene': -0.1411366681,
#               'unitprice': 14.8864035176296},
#              52: {'mat_id': 'mp-1121',
#               'composition': 'GaCo',
#               'ehull': 0.0,
#               'formation_ene': -0.2818518375,
#               'unitprice': 396.8009038639633},
#              53: {'mat_id': 'mp-11299',
#               'composition': 'Cd2Hg',
#               'ehull': 0.0039124367,
#               'formation_ene': 0.0039124367,
#               'unitprice': 26.765484707737443},
#              54: {'mat_id': 'mp-11359',
#               'composition': 'Ga2Cu',
#               'ehull': 0.0,
#               'formation_ene': -0.07553995,
#               'unitprice': 475.6490026056117},
#              55: {'mat_id': 'mp-11393',
#               'composition': 'Nb3Ga2',
#               'ehull': 0.0,
#               'formation_ene': -0.362982629,
#               'unitprice': 257.6296178717624},
#              56: {'mat_id': 'mp-11397',
#               'composition': 'Ga3Ni2',
#               'ehull': 0.0,
#               'formation_ene': -0.408390522,
#               'unitprice': 447.3896956953194},
#              57: {'mat_id': 'mp-11398',
#               'composition': 'Ga3Ni5',
#               'ehull': 0.0,
#               'formation_ene': -0.3758569787,
#               'unitprice': 297.1582218637283},
#              58: {'mat_id': 'mp-11416',
#               'composition': 'TaGa3',
#               'ehull': 0.0,
#               'formation_ene': -0.16907248,
#               'unitprice': 439.32758860226204},
#              59: {'mat_id': 'mp-11478',
#               'composition': 'GaAg',
#               'ehull': 0.0885381125,
#               'formation_ene': 0.0517079333,
#               'unitprice': 789.7821997653905},
#              60: {'mat_id': 'mp-11501',
#               'composition': 'MnNi3',
#               'ehull': 0.0,
#               'formation_ene': -0.1119101724,
#               'unitprice': 14.621755904410671},
#              61: {'mat_id': 'mp-11504',
#               'composition': 'MnZn3',
#               'ehull': 0.0,
#               'formation_ene': -0.0296719487,
#               'unitprice': 2.7549876060694714},
#              62: {'mat_id': 'mp-11506',
#               'composition': 'Ni3Mo',
#               'ehull': 0.0,
#               'formation_ene': -0.09327553,
#               'unitprice': 26.557642359752474},
#              63: {'mat_id': 'mp-11507',
#               'composition': 'Ni4Mo',
#               'ehull': 0.0,
#               'formation_ene': -0.083113574,
#               'unitprice': 25.13490582570575},
#              64: {'mat_id': 'mp-1451',
#               'composition': 'NbNi3',
#               'ehull': 0.0,
#               'formation_ene': -0.2928548988,
#               'unitprice': 26.7403740422862},
#              65: {'mat_id': 'mp-11531',
#               'composition': 'VNi2',
#               'ehull': 0.0,
#               'formation_ene': -0.24297792,
#               'unitprice': 124.90374470664507},
#              66: {'mat_id': 'mp-11532',
#               'composition': 'Zn11Ni2',
#               'ehull': 0.0,
#               'formation_ene': -0.1626148569,
#               'unitprice': 5.136529730098728},
#              67: {'mat_id': 'mp-11567',
#               'composition': 'ScZn12',
#               'ehull': 0.0,
#               'formation_ene': -0.1368375181,
#               'unitprice': 190.2270843335713},
#              68: {'mat_id': 'mp-1157',
#               'composition': 'TaNi2',
#               'ehull': 0.002502422,
#               'formation_ene': -0.3333485067,
#               'unitprice': 99.36614876320635},
#              69: {'mat_id': 'mp-11578',
#               'composition': 'VZn3',
#               'ehull': 0.0,
#               'formation_ene': -0.0524799413,
#               'unitprice': 78.59876648259336},
#              70: {'mat_id': 'mp-11697',
#               'composition': 'TaSb2',
#               'ehull': 0.0,
#               'formation_ene': -0.1430962967,
#               'unitprice': 72.91487149210538},
#              71: {'mat_id': 'mp-1182452',
#               'composition': 'CrGa',
#               'ehull': 0.0822481861,
#               'formation_ene': -0.0154597627,
#               'unitprice': 398.15035876165706},
#              72: {'mat_id': 'mp-2593',
#               'composition': 'AlNi3',
#               'ehull': 0.0,
#               'formation_ene': -0.433437135,
#               'unitprice': 16.413589809239394},
#              73: {'mat_id': 'mp-1183248',
#               'composition': 'AgSn3',
#               'ehull': 0.0999843579,
#               'formation_ene': 0.0921432117,
#               'unitprice': 224.03300003915035},
#              74: {'mat_id': 'mp-985443',
#               'composition': 'Ag3Hg',
#               'ehull': 0.021153115,
#               'formation_ene': 0.021153115,
#               'unitprice': 548.7017228448674},
#              75: {'mat_id': 'mp-1183256',
#               'composition': 'AgPb3',
#               'ehull': 0.0893205192,
#               'formation_ene': 0.0893205192,
#               'unitprice': 128.4868959557955},
#              76: {'mat_id': 'mp-1183465',
#               'composition': 'Bi3Pb',
#               'ehull': 0.09152145,
#               'formation_ene': 0.09152145,
#               'unitprice': 19.598724742685192},
#              77: {'mat_id': 'mp-1183623',
#               'composition': 'CdCu3',
#               'ehull': 0.07591285,
#               'formation_ene': 0.07591285,
#               'unitprice': 7.006355678054976},
#              78: {'mat_id': 'mp-1183624',
#               'composition': 'Cd3Ni',
#               'ehull': 0.0833591998,
#               'formation_ene': 0.0731638175,
#               'unitprice': 5.073887710068791},
#              79: {'mat_id': 'mp-1183627',
#               'composition': 'CdAg3',
#               'ehull': 0.0,
#               'formation_ene': -0.05556183,
#               'unitprice': 635.6670904332051},
#              80: {'mat_id': 'mp-1183662',
#               'composition': 'Cd3Ga',
#               'ehull': 0.0396449363,
#               'formation_ene': 0.0396449363,
#               'unitprice': 120.1466155632206},
#              81: {'mat_id': 'mp-1183658',
#               'composition': 'Cd3Bi',
#               'ehull': 0.0596650225,
#               'formation_ene': 0.0596650225,
#               'unitprice': 11.368704779602698},
#              82: {'mat_id': 'mp-1183660',
#               'composition': 'CdPb3',
#               'ehull': 0.039892435,
#               'formation_ene': 0.039892435,
#               'unitprice': 2.3832860061116254},
#              83: {'mat_id': 'mp-1183661',
#               'composition': 'Cd3Hg',
#               'ehull': 0.0080323438,
#               'formation_ene': 0.0080323438,
#               'unitprice': 21.74180057470209},
#              84: {'mat_id': 'mp-1183663',
#               'composition': 'Cd3Pb',
#               'ehull': 0.06168892,
#               'formation_ene': 0.06168892,
#               'unitprice': 2.5741853663242313},
#              85: {'mat_id': 'mp-1183669',
#               'composition': 'CdIn',
#               'ehull': 0.030965075,
#               'formation_ene': 0.030965075,
#               'unitprice': 365.1785615025194},
#              86: {'mat_id': 'mp-1183676',
#               'composition': 'CdIn3',
#               'ehull': 0.0455859637,
#               'formation_ene': 0.0455859637,
#               'unitprice': 543.5384938547886},
#              87: {'mat_id': 'mp-1183741',
#               'composition': 'CdSn3',
#               'ehull': 0.048756275,
#               'formation_ene': 0.048756275,
#               'unitprice': 25.554139737901913},
#              88: {'mat_id': 'mp-1183726',
#               'composition': 'CdSn',
#               'ehull': 0.06944843,
#               'formation_ene': 0.06944843,
#               'unitprice': 18.1534437905344},
#              89: {'mat_id': 'mp-1183751',
#               'composition': 'CoNi3',
#               'ehull': 0.0192432962,
#               'formation_ene': 0.0106209213,
#               'unitprice': 26.98516178495973},
#              90: {'mat_id': 'mp-985707',
#               'composition': 'CoSn3',
#               'ehull': 0.0,
#               'formation_ene': -0.0682124419,
#               'unitprice': 35.52093947402059},
#              91: {'mat_id': 'mp-1224795',
#               'composition': 'GaAg3',
#               'ehull': 0.0210966867,
#               'formation_ene': -0.0157334925,
#               'unitprice': 825.8449846861348},
#              92: {'mat_id': 'mp-20900',
#               'composition': 'Cu3Sb',
#               'ehull': 0.0805904838,
#               'formation_ene': 0.0805904838,
#               'unitprice': 11.387567850120941},
#              93: {'mat_id': 'mp-1184031',
#               'composition': 'Ga3Sn',
#               'ehull': 0.0377255525,
#               'formation_ene': 0.0377255525,
#               'unitprice': 450.80648663607644},
#              94: {'mat_id': 'mp-1183995',
#               'composition': 'GaCu3',
#               'ehull': 0.0,
#               'formation_ene': -0.0946284075,
#               'unitprice': 191.23496623927886},
#              95: {'mat_id': 'mp-1184011',
#               'composition': 'Cu3Ag',
#               'ehull': 0.0904573517,
#               'formation_ene': 0.0904573517,
#               'unitprice': 315.2397359040056},
#              96: {'mat_id': 'mp-1184014',
#               'composition': 'GaPb3',
#               'ehull': 0.037488335,
#               'formation_ene': 0.037488335,
#               'unitprice': 71.48064813087083},
#              97: {'mat_id': 'mp-1184021',
#               'composition': 'Cu3Ge',
#               'ehull': 0.0,
#               'formation_ene': -0.0039732525,
#               'unitprice': 406.9570213509632},
#              98: {'mat_id': 'mp-815',
#               'composition': 'GaNi3',
#               'ehull': 0.0,
#               'formation_ene': -0.289444615,
#               'unitprice': 208.45318534624997},
#              99: {'mat_id': 'mp-1184054',
#               'composition': 'CuNi3',
#               'ehull': 0.0316992575,
#               'formation_ene': 0.0316992575,
#               'unitprice': 16.15091490739174},
#              100: {'mat_id': 'mp-1225687',
#               'composition': 'CuNi',
#               'ehull': 0.018717835,
#               'formation_ene': 0.018717835,
#               'unitprice': 13.855617384231877},
#              101: {'mat_id': 'mp-1184225',
#               'composition': 'Fe3W',
#               'ehull': 0.064312495,
#               'formation_ene': 0.064312495,
#               'unitprice': 18.56961994919957},
#              102: {'mat_id': 'mp-1184257',
#               'composition': 'Ga3Ag',
#               'ehull': 0.0470645662,
#               'formation_ene': 0.0286494767,
#               'unitprice': 745.0414291485902},
#              103: {'mat_id': 'mp-1184266',
#               'composition': 'GaSn3',
#               'ehull': 0.0470114825,
#               'formation_ene': 0.0470114825,
#               'unitprice': 140.04837385220324},
#              104: {'mat_id': 'mp-1184268',
#               'composition': 'Ga3Hg',
#               'ehull': 0.0821258025,
#               'formation_ene': 0.0821258025,
#               'unitprice': 377.5238964853146},
#              105: {'mat_id': 'mp-1184324',
#               'composition': 'Fe3Sb',
#               'ehull': 0.0820213006,
#               'formation_ene': 0.089005385,
#               'unitprice': 6.140495269580186},
#              106: {'mat_id': 'mp-1184425',
#               'composition': 'Ga3Pb',
#               'ehull': 0.0910729825,
#               'formation_ene': 0.0910729825,
#               'unitprice': 346.81267181510157},
#              107: {'mat_id': 'mp-1184355',
#               'composition': 'Ga3Ge',
#               'ehull': 0.0944078463,
#               'formation_ene': 0.0944078463,
#               'unitprice': 884.4560095483042},
#              108: {'mat_id': 'mp-1184488',
#               'composition': 'In3Bi',
#               'ehull': 0.0388852187,
#               'formation_ene': 0.03740426,
#               'unitprice': 457.6981928955465},
#              109: {'mat_id': 'mp-1184493',
#               'composition': 'In3Ag',
#               'ehull': 0.0738731567,
#               'formation_ene': 0.0618534892,
#               'unitprice': 752.3430434473421},
#              110: {'mat_id': 'mp-1223722',
#               'composition': 'InSn3',
#               'ehull': 0.0383516525,
#               'formation_ene': 0.0383516525,
#               'unitprice': 200.31629283613543},
#              111: {'mat_id': 'mp-1184785',
#               'composition': 'InGa3',
#               'ehull': 0.053415855,
#               'formation_ene': 0.053415855,
#               'unitprice': 699.3907079638813},
#              112: {'mat_id': 'mp-1223654',
#               'composition': 'InPb',
#               'ehull': 0.0242719133,
#               'formation_ene': 0.02308733,
#               'unitprice': 258.22501441906974},
#              113: {'mat_id': 'mp-1184858',
#               'composition': 'InCu3',
#               'ehull': 0.0247254542,
#               'formation_ene': 0.0192815575,
#               'unitprice': 276.59847694442044},
#              114: {'mat_id': 'mp-1224025',
#               'composition': 'In3Sn',
#               'ehull': 0.0342447225,
#               'formation_ene': 0.0342447225,
#               'unitprice': 543.8799043476611},
#              115: {'mat_id': 'mp-974309',
#               'composition': 'In3Ga',
#               'ehull': 0.046305885,
#               'formation_ene': 0.046305885,
#               'unitprice': 714.6475346485053},
#              116: {'mat_id': 'mp-1184921',
#               'composition': 'In3Pb',
#               'ehull': 0.0,
#               'formation_ene': -0.001776875,
#               'unitprice': 450.45926855694336},
#              117: {'mat_id': 'mp-1184933',
#               'composition': 'In3Hg',
#               'ehull': 0.029148465,
#               'formation_ene': 0.029148465,
#               'unitprice': 474.8046511574405},
#              118: {'mat_id': 'mp-1218972',
#               'composition': 'Sn3Sb',
#               'ehull': 0.0252371663,
#               'formation_ene': 0.0252371663,
#               'unitprice': 28.055298345434096},
#              119: {'mat_id': 'mp-1187047',
#               'composition': 'Sn3Hg',
#               'ehull': 0.0515021838,
#               'formation_ene': 0.0515021838,
#               'unitprice': 40.305493744475314},
#              120: {'mat_id': 'mp-1187117',
#               'composition': 'Sn3Pb',
#               'ehull': 0.03978893,
#               'formation_ene': 0.03978893,
#               'unitprice': 21.56303681408819},
#              121: {'mat_id': 'mp-1187118',
#               'composition': 'SnPb3',
#               'ehull': 0.0339468775,
#               'formation_ene': 0.0339468775,
#               'unitprice': 7.201356414129352},
#              122: {'mat_id': 'mp-1187206',
#               'composition': 'Ta3W',
#               'ehull': 0.0,
#               'formation_ene': -0.042805005,
#               'unitprice': 122.32725722571654},
#              123: {'mat_id': 'mp-1187257',
#               'composition': 'TaZn3',
#               'ehull': 0.0010692847,
#               'formation_ene': -0.0660335913,
#               'unitprice': 74.35986298279694},
#              124: {'mat_id': 'mp-1187484',
#               'composition': 'TlBi3',
#               'ehull': 0.09271704,
#               'formation_ene': 0.07816083,
#               'unitprice': 1494.4422820770963},
#              125: {'mat_id': 'mp-1187690',
#               'composition': 'TlSn3',
#               'ehull': 0.05443598,
#               'formation_ene': 0.05443598,
#               'unitprice': 2208.98502262078},
#              126: {'mat_id': 'mp-1187695',
#               'composition': 'V3Cr',
#               'ehull': 0.0,
#               'formation_ene': -0.029685985,
#               'unitprice': 278.45748103462256},
#              127: {'mat_id': 'mp-1187696',
#               'composition': 'VCr3',
#               'ehull': 0.0,
#               'formation_ene': -0.0544977725,
#               'unitprice': 98.17167474186901},
#              128: {'mat_id': 'mp-1187702',
#               'composition': 'VW3',
#               'ehull': 0.0,
#               'formation_ene': -0.0869654175,
#               'unitprice': 63.600762870324495},
#              129: {'mat_id': 'mp-1187742',
#               'composition': 'TlIn3',
#               'ehull': 0.04334053,
#               'formation_ene': 0.04334053,
#               'unitprice': 2686.617758100224},
#              130: {'mat_id': 'mp-864794',
#               'composition': 'ZnAg3',
#               'ehull': 0.0,
#               'formation_ene': -0.0284244288,
#               'unitprice': 712.1777076086951},
#              131: {'mat_id': 'mp-971941',
#               'composition': 'Zn3Ni',
#               'ehull': 0.0285064014,
#               'formation_ene': -0.1691454213,
#               'unitprice': 6.539391191935446},
#              132: {'mat_id': 'mp-1187951',
#               'composition': 'ZnCo3',
#               'ehull': 0.0741625407,
#               'formation_ene': 0.0472036275,
#               'unitprice': 38.910228895373564},
#              133: {'mat_id': 'mp-1187969',
#               'composition': 'Zn3Ag',
#               'ehull': 0.0,
#               'formation_ene': -0.0414082058,
#               'unitprice': 305.3761217381342},
#              134: {'mat_id': 'mp-1912',
#               'composition': 'ZnAg',
#               'ehull': 0.0,
#               'formation_ene': -0.0496258892,
#               'unitprice': 533.6972012067775},
#              135: {'mat_id': 'mp-1187978',
#               'composition': 'ZnCo',
#               'ehull': 0.0904253464,
#               'formation_ene': 0.03650752,
#               'unitprice': 26.299057545750518},
#              136: {'mat_id': 'mp-981215',
#               'composition': 'Zn3Co',
#               'ehull': 0.0258388745,
#               'formation_ene': -0.055037865,
#               'unitprice': 14.328013363938627},
#              137: {'mat_id': 'mp-2717',
#               'composition': 'Zr2Ni7',
#               'ehull': 0.0,
#               'formation_ene': -0.4262416811,
#               'unitprice': 23.909935947206737},
#              138: {'mat_id': 'mp-1188070',
#               'composition': 'Zn3Sn',
#               'ehull': 0.0942840588,
#               'formation_ene': 0.0942840588,
#               'unitprice': 14.185517311922641},
#              139: {'mat_id': 'mp-1188074',
#               'composition': 'Zn3In',
#               'ehull': 0.0662530475,
#               'formation_ene': 0.0662530475,
#               'unitprice': 267.6495733254316},
#              140: {'mat_id': 'mp-1188928',
#               'composition': 'In9Cu11',
#               'ehull': 0.0152007054,
#               'formation_ene': 0.0100678885,
#               'unitprice': 433.34359775278296},
#              141: {'mat_id': 'mp-1189774',
#               'composition': 'V3Ga2',
#               'ehull': 0.089509178,
#               'formation_ene': -0.112541804,
#               'unitprice': 521.7514083230844},
#              142: {'mat_id': 'mp-1190774',
#               'composition': 'Ta6Ga5',
#               'ehull': 0.055197915,
#               'formation_ene': -0.2056809432,
#               'unitprice': 282.14138310491285},
#              143: {'mat_id': 'mp-1191009',
#               'composition': 'NbCo2',
#               'ehull': 0.0127648888,
#               'formation_ene': -0.1482268683,
#               'unitprice': 47.83535694627257},
#              144: {'mat_id': 'mp-1191566',
#               'composition': 'Zn6Sb5',
#               'ehull': 0.0222819569,
#               'formation_ene': -0.003298705,
#               'unitprice': 9.850547686722612},
#              145: {'mat_id': 'mp-1192223',
#               'composition': 'Nb6Sn5',
#               'ehull': 0.0005286745,
#               'formation_ene': -0.1590333327,
#               'unitprice': 37.369877250149315},
#              146: {'mat_id': 'mp-1192361',
#               'composition': 'Zn11Co2',
#               'ehull': 0.0,
#               'formation_ene': -0.0912455523,
#               'unitprice': 9.883997860717061},
#              147: {'mat_id': 'mp-1193426',
#               'composition': 'Fe25Mo4',
#               'ehull': 0.0933988338,
#               'formation_ene': 0.0933988338,
#               'unitprice': 9.063815413940787},
#              148: {'mat_id': 'mp-1193737',
#               'composition': 'LiZn13',
#               'ehull': 0.0150520911,
#               'formation_ene': -0.033875803,
#               'unitprice': 2.9570099128281697},
#              149: {'mat_id': 'mp-1195396',
#               'composition': 'Nb4Ga5',
#               'ehull': 0.0030374811,
#               'formation_ene': -0.3357173328,
#               'unitprice': 354.85510722352865},
#              150: {'mat_id': 'mp-1195805',
#               'composition': 'Ga41Mo8',
#               'ehull': 0.0026375053,
#               'formation_ene': -0.1333375927,
#               'unitprice': 551.1609106064924},
#              151: {'mat_id': 'mp-13138',
#               'composition': 'Cu3Sn',
#               'ehull': 0.0119794725,
#               'formation_ene': -0.0039954,
#               'unitprice': 18.442489055015653},
#              152: {'mat_id': 'mp-1196402',
#               'composition': 'Mn6Ga29',
#               'ehull': 0.0061248526,
#               'formation_ene': -0.1440108914,
#               'unitprice': 591.9035098405494},
#              153: {'mat_id': 'mp-1197621',
#               'composition': 'Ga4Cu9',
#               'ehull': 0.0,
#               'formation_ene': -0.1080556483,
#               'unitprice': 231.94961146045125},
#              154: {'mat_id': 'mp-1198302',
#               'composition': 'Nb3Ge',
#               'ehull': 0.0,
#               'formation_ene': -0.3194392756,
#               'unitprice': 333.30764884772884},
#              155: {'mat_id': 'mp-1200317',
#               'composition': 'Ni5Ge2',
#               'ehull': 0.0163693715,
#               'formation_ene': -0.2810404905,
#               'unitprice': 492.5255038917164},
#              156: {'mat_id': 'mp-1201271',
#               'composition': 'HfZn22',
#               'ehull': 0.0038855046,
#               'formation_ene': -0.0499071983,
#               'unitprice': 101.93919062434323},
#              157: {'mat_id': 'mp-1203833',
#               'composition': 'Ga31Mo6',
#               'ehull': 0.0,
#               'formation_ene': -0.1359197666,
#               'unitprice': 552.0327559656185},
#              158: {'mat_id': 'mp-1204207',
#               'composition': 'Nb10Ge7',
#               'ehull': 0.0012666872,
#               'formation_ene': -0.4587856288,
#               'unitprice': 540.2033126027326},
#              159: {'mat_id': 'mp-1206982',
#               'composition': 'SbPb',
#               'ehull': 0.0810180825,
#               'formation_ene': 0.0810180825,
#               'unitprice': 6.754291527563231},
#              160: {'mat_id': 'mp-1207221',
#               'composition': 'In2Sb',
#               'ehull': 0.0817480617,
#               'formation_ene': 0.01328107,
#               'unitprice': 475.49095895421465},
#              161: {'mat_id': 'mp-1207450',
#               'composition': 'Zn9Fe4',
#               'ehull': 0.0,
#               'formation_ene': -0.0391216169,
#               'unitprice': 2.196243368735407},
#              162: {'mat_id': 'mp-1207504',
#               'composition': 'Zn22Ni3',
#               'ehull': 0.0,
#               'formation_ene': -0.1292913876,
#               'unitprice': 4.649395663778468},
#              163: {'mat_id': 'mp-1207538',
#               'composition': 'Zn17Co3',
#               'ehull': 0.0055338988,
#               'formation_ene': -0.0855706727,
#               'unitprice': 9.708023686064283},
#              164: {'mat_id': 'mp-1208498',
#               'composition': 'Ti3Zn22',
#               'ehull': 0.0,
#               'formation_ene': -0.122104955,
#               'unitprice': 3.7254093201043297},
#              165: {'mat_id': 'mp-1210567',
#               'composition': 'MnZn13',
#               'ehull': 0.0,
#               'formation_ene': -0.021810791,
#               'unitprice': 2.8955787782758518},
#              166: {'mat_id': 'mp-1212307',
#               'composition': 'In7Ni3',
#               'ehull': 0.0,
#               'formation_ene': -0.1303988695,
#               'unitprice': 593.9650731611489},
#              167: {'mat_id': 'mp-1212970',
#               'composition': 'Fe7Ge4',
#               'ehull': 0.0112235447,
#               'formation_ene': -0.0785833286,
#               'unitprice': 618.3473401332258},
#              168: {'mat_id': 'mp-1213091',
#               'composition': 'In3Ni7',
#               'ehull': 0.021994556,
#               'formation_ene': -0.082929181,
#               'unitprice': 338.45077728620106},
#              169: {'mat_id': 'mp-1213182',
#               'composition': 'Fe13Mo9',
#               'ehull': 0.0127315389,
#               'formation_ene': 0.0127315389,
#               'unitprice': 22.51643316680162},
#              170: {'mat_id': 'mp-1213530',
#               'composition': 'Cu41Sn11',
#               'ehull': 0.0274422691,
#               'formation_ene': 0.0139250693,
#               'unitprice': 17.28379681077378},
#              171: {'mat_id': 'mp-1215401',
#               'composition': 'ZnCu2',
#               'ehull': 0.0273623167,
#               'formation_ene': -0.032982215,
#               'unitprice': 7.292703790474931},
#              172: {'mat_id': 'mp-987',
#               'composition': 'ZnCu',
#               'ehull': 0.0,
#               'formation_ene': -0.0905167975,
#               'unitprice': 6.191232769135908},
#              173: {'mat_id': 'mp-1215473',
#               'composition': 'ZnFe',
#               'ehull': 0.0190916936,
#               'formation_ene': -0.0091628075,
#               'unitprice': 1.6882808622200256},
#              174: {'mat_id': 'mp-972042',
#               'composition': 'Zn3Cu',
#               'ehull': 0.0,
#               'formation_ene': -0.0808158563,
#               'unitprice': 4.5587746377767315},
#              175: {'mat_id': 'mp-1215518',
#               'composition': 'ZnCu3',
#               'ehull': 0.023764705,
#               'formation_ene': -0.0214936938,
#               'unitprice': 7.847446457082134},
#              176: {'mat_id': 'mp-1215582',
#               'composition': 'ZnNi4',
#               'ehull': 0.072768148,
#               'formation_ene': -0.029245123,
#               'unitprice': 15.143742812957006},
#              177: {'mat_id': 'mp-1215735',
#               'composition': 'Zn10Fe3',
#               'ehull': 0.0707118399,
#               'formation_ene': 0.0341918635,
#               'unitprice': 2.391150367657106},
#              178: {'mat_id': 'mp-1215897',
#               'composition': 'Zn53Co7',
#               'ehull': 0.0,
#               'formation_ene': -0.0898827378,
#               'unitprice': 8.188593621602676},
#              179: {'mat_id': 'mp-1216020',
#               'composition': 'Zn35Cu17',
#               'ehull': 0.0,
#               'formation_ene': -0.1014189399,
#               'unitprice': 5.058570045546677},
#              180: {'mat_id': 'mp-1216231',
#               'composition': 'VW',
#               'ehull': 0.0,
#               'formation_ene': -0.06931189,
#               'unitprice': 107.92122462800519},
#              181: {'mat_id': 'mp-1216325',
#               'composition': 'VGa',
#               'ehull': 0.0890340743,
#               'formation_ene': -0.126238555,
#               'unitprice': 553.7842115381576},
#              182: {'mat_id': 'mp-1216329',
#               'composition': 'VFe4',
#               'ehull': 0.057472256,
#               'formation_ene': -0.045356054,
#               'unitprice': 68.88080571956627},
#              183: {'mat_id': 'mp-1335',
#               'composition': 'VFe',
#               'ehull': 0.0206316056,
#               'formation_ene': -0.129277935,
#               'unitprice': 176.61537494486666},
#              184: {'mat_id': 'mp-866134',
#               'composition': 'VFe3',
#               'ehull': 0.0,
#               'formation_ene': -0.1285353875,
#               'unitprice': 86.43356704107767},
#              185: {'mat_id': 'mp-1216394',
#               'composition': 'VCr',
#               'ehull': 0.0,
#               'formation_ene': -0.042334595,
#               'unitprice': 187.85281898936833},
#              186: {'mat_id': 'mp-22568',
#               'composition': 'V3Ga',
#               'ehull': 0.0,
#               'formation_ene': -0.1752658262,
#               'unitprice': 469.64717641468},
#              187: {'mat_id': 'mp-1216505',
#               'composition': 'V6Ga7',
#               'ehull': 0.0393907332,
#               'formation_ene': -0.1788278573,
#               'unitprice': 565.5797582895793},
#              188: {'mat_id': 'mp-1216530',
#               'composition': 'TlPb',
#               'ehull': 0.0,
#               'formation_ene': -0.004320525,
#               'unitprice': 2981.121998619371},
#              189: {'mat_id': 'mp-1216708',
#               'composition': 'V3Ni2',
#               'ehull': 0.0,
#               'formation_ene': -0.1885925677,
#               'unitprice': 217.3171329626243},
#              190: {'mat_id': 'mp-1217811',
#               'composition': 'TaW',
#               'ehull': 0.0,
#               'formation_ene': -0.06753677,
#               'unitprice': 93.08818095601202},
#              191: {'mat_id': 'mp-1217892',
#               'composition': 'TaNb',
#               'ehull': 0.00760893,
#               'formation_ene': 0.00760893,
#               'unitprice': 114.64481118679694},
#              192: {'mat_id': 'mp-1217895',
#               'composition': 'TaMo',
#               'ehull': 0.0,
#               'formation_ene': -0.107180185,
#               'unitprice': 113.50219935619069},
#              193: {'mat_id': 'mp-1217954',
#               'composition': 'TaNi',
#               'ehull': 0.0274324779,
#               'formation_ene': -0.2580958831,
#               'unitprice': 119.16197488617898},
#              194: {'mat_id': 'mp-1218179',
#               'composition': 'TaCo',
#               'ehull': 0.0,
#               'formation_ene': -0.2476569198,
#               'unitprice': 127.3341077638255},
#              195: {'mat_id': 'mp-1218218',
#               'composition': 'TaFe',
#               'ehull': 0.0,
#               'formation_ene': -0.1911240488,
#               'unitprice': 116.04939692675725},
#              196: {'mat_id': 'mp-1218673',
#               'composition': 'Sr4Zn51',
#               'ehull': 0.0064552261,
#               'formation_ene': -0.1637791644,
#               'unitprice': 2.779427862304605},
#              197: {'mat_id': 'mp-1218964',
#               'composition': 'SnBi',
#               'ehull': 0.046069485,
#               'formation_ene': 0.046069485,
#               'unitprice': 28.007695231764924},
#              198: {'mat_id': 'mp-1219484',
#               'composition': 'SbPb4',
#               'ehull': 0.059193469,
#               'formation_ene': 0.059193469,
#               'unitprice': 3.854956925958593},
#              199: {'mat_id': 'mp-1219498',
#               'composition': 'SbPb3',
#               'ehull': 0.0962799162,
#               'formation_ene': 0.0962799163,
#               'unitprice': 4.282638942094275},
#              200: {'mat_id': 'mp-1219818',
#               'composition': 'Ni7Ge4',
#               'ehull': 0.0437037453,
#               'formation_ene': -0.2675529918,
#               'unitprice': 611.5127111796239},
#              201: {'mat_id': 'mp-1220316',
#               'composition': 'NbW',
#               'ehull': 0.0,
#               'formation_ene': -0.041518565,
#               'unitprice': 37.643252086621686},
#              202: {'mat_id': 'mp-1220327',
#               'composition': 'NbMo',
#               'ehull': 0.0,
#               'formation_ene': -0.07430704,
#               'unitprice': 41.76715972777979},
#              203: {'mat_id': 'mp-1220533',
#               'composition': 'NiBi',
#               'ehull': 0.0,
#               'formation_ene': -0.0211366744,
#               'unitprice': 23.825016891136972},
#              204: {'mat_id': 'mp-22060',
#               'composition': 'Nb3In',
#               'ehull': 0.0322823862,
#               'formation_ene': 0.0322823862,
#               'unitprice': 240.0193347973612},
#              205: {'mat_id': 'mp-1220799',
#               'composition': 'NbNi',
#               'ehull': 0.0,
#               'formation_ene': -0.2034333585,
#               'unitprice': 33.089241629847876},
#              206: {'mat_id': 'mp-1221',
#               'composition': 'V3Ge',
#               'ehull': 0.0,
#               'formation_ene': -0.3375661338,
#               'unitprice': 717.9467659669706},
#              207: {'mat_id': 'mp-1221030',
#               'composition': 'Ni4Sn3',
#               'ehull': 0.0,
#               'formation_ene': -0.2660761354,
#               'unitprice': 27.109735288706013},
#              208: {'mat_id': 'mp-1221111',
#               'composition': 'NbFe',
#               'ehull': 0.0,
#               'formation_ene': -0.1085648031,
#               'unitprice': 26.486238197924617},
#              209: {'mat_id': 'mp-1221162',
#               'composition': 'Nb19Fe20',
#               'ehull': 0.0015223089,
#               'formation_ene': -0.1086779033,
#               'unitprice': 25.977119696790545},
#              210: {'mat_id': 'mp-1221387',
#               'composition': 'MoW',
#               'ehull': 0.00013021,
#               'formation_ene': 0.00013021,
#               'unitprice': 37.34736997309671},
#              211: {'mat_id': 'mp-1221635',
#               'composition': 'MnFe4',
#               'ehull': 0.0391290421,
#               'formation_ene': 0.0391290421,
#               'unitprice': 0.5759717049607761},
#              212: {'mat_id': 'mp-23188',
#               'composition': 'In2Bi',
#               'ehull': 0.0289701517,
#               'formation_ene': 0.02699554,
#               'unitprice': 389.027057457439},
#              213: {'mat_id': 'mp-30343',
#               'composition': 'InAg3',
#               'ehull': 0.0,
#               'formation_ene': -0.0333992325,
#               'unitprice': 820.0447767226055},
#              214: {'mat_id': 'mp-1223819',
#               'composition': 'InAg4',
#               'ehull': 0.0999791813,
#               'formation_ene': 0.0732597953,
#               'unitprice': 827.05180414712},
#              215: {'mat_id': 'mp-1223890',
#               'composition': 'In4Pb',
#               'ehull': 0.041526994,
#               'formation_ene': 0.040105494,
#               'unitprice': 496.8999967863136},
#              216: {'mat_id': 'mp-1223901',
#               'composition': 'InBi3',
#               'ehull': 0.0649936613,
#               'formation_ene': 0.0635127025,
#               'unitprice': 132.84574795357457},
#              217: {'mat_id': 'mp-1223969',
#               'composition': 'HgPb2',
#               'ehull': 0.0329635633,
#               'formation_ene': 0.0329635633,
#               'unitprice': 19.080383524245924},
#              218: {'mat_id': 'mp-1223984',
#               'composition': 'HgPb3',
#               'ehull': 0.03214129,
#               'formation_ene': 0.03214129,
#               'unitprice': 14.856748969362314},
#              219: {'mat_id': 'mp-1223990',
#               'composition': 'In4Bi',
#               'ehull': 0.068997735,
#               'formation_ene': 0.067812968,
#               'unitprice': 502.7714110534987},
#              220: {'mat_id': 'mp-1224108',
#               'composition': 'HgPb4',
#               'ehull': 0.032052726,
#               'formation_ene': 0.032052726,
#               'unitprice': 12.333416690140766},
#              221: {'mat_id': 'mp-22236',
#               'composition': 'In3Co',
#               'ehull': 0.0,
#               'formation_ene': -0.011536985,
#               'unitprice': 622.463949148213},
#              222: {'mat_id': 'mp-1224231',
#               'composition': 'In9Ag17',
#               'ehull': 0.0053845368,
#               'formation_ene': -0.0260515168,
#               'unitprice': 806.6938435623981},
#              223: {'mat_id': 'mp-1224697',
#               'composition': 'Fe2Ni',
#               'ehull': 0.0890880967,
#               'formation_ene': 0.0439261767,
#               'unitprice': 6.525315718267038},
#              224: {'mat_id': 'mp-1224870',
#               'composition': 'Ga5Ag13',
#               'ehull': 0.013998885,
#               'formation_ene': -0.0269235363,
#               'unitprice': 822.1871930378683},
#              225: {'mat_id': 'mp-2213',
#               'composition': 'FeNi',
#               'ehull': 0.0,
#               'formation_ene': -0.06774288,
#               'unitprice': 9.603964623233608},
#              226: {'mat_id': 'mp-2090',
#               'composition': 'FeCo',
#               'ehull': 0.0,
#               'formation_ene': -0.0682856725,
#               'unitprice': 26.912230211516263},
#              227: {'mat_id': 'mp-1225131',
#               'composition': 'Fe3Cu',
#               'ehull': 0.0698697725,
#               'formation_ene': 0.0698697725,
#               'unitprice': 2.77309930403752},
#              228: {'mat_id': 'mp-1225698',
#               'composition': 'Cu3Ni',
#               'ehull': 0.05043035,
#               'formation_ene': 0.05043035,
#               'unitprice': 11.649664089363242},
#              229: {'mat_id': 'mp-1225722',
#               'composition': 'Cu5Ge2',
#               'ehull': 0.0680122986,
#               'formation_ene': 0.0642282486,
#               'unitprice': 461.5023411672566},
#              230: {'mat_id': 'mp-1225980',
#               'composition': 'Cu19Sn16',
#               'ehull': 0.0164128186,
#               'formation_ene': -0.0127983769,
#               'unitprice': 23.730369416529765},
#              231: {'mat_id': 'mp-1226076',
#               'composition': 'CoNi',
#               'ehull': 0.0234877675,
#               'formation_ene': 0.0062430175,
#               'unitprice': 35.412012696653214},
#              232: {'mat_id': 'mp-1226096',
#               'composition': 'Co7Ge4',
#               'ehull': 0.0511064832,
#               'formation_ene': -0.1090245314,
#               'unitprice': 629.8544512786825},
#              233: {'mat_id': 'mp-1226395',
# ...
#               'unitprice': 130.43904437486293},
#              348: {'mat_id': 'mp-30883',
#               'composition': 'V4Zn5',
#               'ehull': 0.0,
#               'formation_ene': -0.0472187106,
#               'unitprice': 143.85169176145206},
#              349: {'mat_id': 'mp-30886',
#               'composition': 'YZn12',
#               'ehull': 0.0,
#               'formation_ene': -0.1861208687,
#               'unitprice': 5.803545232673438},
#              350: {'mat_id': 'mp-30888',
#               'composition': 'ZrZn22',
#               'ehull': 0.0,
#               'formation_ene': -0.070285438,
#               'unitprice': 4.919862323628723},
#              351: {'mat_id': 'mp-31216',
#               'composition': 'BaCd11',
#               'ehull': 0.0,
#               'formation_ene': -0.1754051788,
#               'unitprice': 2.483153895845829},
#              352: {'mat_id': 'mp-316',
#               'composition': 'MnV',
#               'ehull': 0.0,
#               'formation_ene': -0.2848886748,
#               'unitprice': 179.0858411102919},
#              353: {'mat_id': 'mp-363',
#               'composition': 'NbGe2',
#               'ehull': 0.0,
#               'formation_ene': -0.3470367189,
#               'unitprice': 900.8952106208592},
#              354: {'mat_id': 'mp-397',
#               'composition': 'KCd13',
#               'ehull': 0.0,
#               'formation_ene': -0.0600857495,
#               'unitprice': 28.716729131622795},
#              355: {'mat_id': 'mp-494',
#               'composition': 'GeMo3',
#               'ehull': 0.0,
#               'formation_ene': -0.1512144275,
#               'unitprice': 325.1537733134856},
#              356: {'mat_id': 'mp-541',
#               'composition': 'Ta3Sb',
#               'ehull': 0.0,
#               'formation_ene': -0.095317545,
#               'unitprice': 126.60889266475158},
#              357: {'mat_id': 'mp-567276',
#               'composition': 'TaV2',
#               'ehull': 0.0,
#               'formation_ene': -0.1027756767,
#               'unitprice': 230.40128497991452},
#              358: {'mat_id': 'mp-567747',
#               'composition': 'Co7Mo6',
#               'ehull': 0.0055743472,
#               'formation_ene': -0.0262879235,
#               'unitprice': 45.83922190568864},
#              359: {'mat_id': 'mp-567857',
#               'composition': 'Cd8Ag5',
#               'ehull': 0.0,
#               'formation_ene': -0.0698296163,
#               'unitprice': 322.4446325280159},
#              360: {'mat_id': 'mp-567982',
#               'composition': 'TaSn2',
#               'ehull': 0.0,
#               'formation_ene': -0.0355152025,
#               'unitprice': 84.24501491038032},
#              361: {'mat_id': 'mp-568014',
#               'composition': 'Nb3Bi',
#               'ehull': 0.0316078712,
#               'formation_ene': 0.0316078712,
#               'unitprice': 35.00790269448079},
#              362: {'mat_id': 'mp-568077',
#               'composition': 'TaFe2',
#               'ehull': 0.0,
#               'formation_ene': -0.1798294942,
#               'unitprice': 93.94359218669847},
#              363: {'mat_id': 'mp-568324',
#               'composition': 'Cr5Ge3',
#               'ehull': 0.0907671306,
#               'formation_ene': 0.0171720806,
#               'unitprice': 666.2959079266082},
#              364: {'mat_id': 'mp-845',
#               'composition': 'Cu5Sn4',
#               'ehull': 0.0110878878,
#               'formation_ene': -0.0173118856,
#               'unitprice': 23.445691815713275},
#              365: {'mat_id': 'mp-569446',
#               'composition': 'NiPb',
#               'ehull': 0.087221075,
#               'formation_ene': 0.087221075,
#               'unitprice': 5.901106896958632},
#              366: {'mat_id': 'mp-569594',
#               'composition': 'Fe7Mo6',
#               'ehull': 0.0283670131,
#               'formation_ene': 0.0283670131,
#               'unitprice': 24.664349346170678},
#              367: {'mat_id': 'mp-570491',
#               'composition': 'TaNi3',
#               'ehull': 0.0,
#               'formation_ene': -0.3610122125,
#               'unitprice': 86.07896667162802},
#              368: {'mat_id': 'mp-569901',
#               'composition': 'Ge23Mo13',
#               'ehull': 0.0372481599,
#               'formation_ene': -0.1313946343,
#               'unitprice': 847.8521286857264},
#              369: {'mat_id': 'mp-570748',
#               'composition': 'Zn13Sb10',
#               'ehull': 0.0109816722,
#               'formation_ene': -0.0134867871,
#               'unitprice': 9.63226697114108},
#              370: {'mat_id': 'mp-570904',
#               'composition': 'GaNi2',
#               'ehull': 0.0199227958,
#               'formation_ene': -0.3271300617,
#               'unitprice': 268.0256191992593},
#              371: {'mat_id': 'mp-571557',
#               'composition': 'V6Ga5',
#               'ehull': 0.0,
#               'formation_ene': -0.2117910386,
#               'unitprice': 539.4746309834104},
#              372: {'mat_id': 'mp-574',
#               'composition': 'Ta2Co',
#               'ehull': 0.0,
#               'formation_ene': -0.2482794517,
#               'unitprice': 137.85394315025758},
#              373: {'mat_id': 'mp-578',
#               'composition': 'GaAg2',
#               'ehull': 0.0,
#               'formation_ene': -0.0491069056,
#               'unitprice': 814.6272191310035},
#              374: {'mat_id': 'mp-579963',
#               'composition': 'Cr11Ge19',
#               'ehull': 0.0284967765,
#               'formation_ene': -0.0146789862,
#               'unitprice': 1027.8988004520015},
#              375: {'mat_id': 'mp-581951',
#               'composition': 'Zn53Ni16',
#               'ehull': 0.0,
#               'formation_ene': -0.1934937534,
#               'unitprice': 6.272914625135274},
#              376: {'mat_id': 'mp-601820',
#               'composition': 'Fe3Co',
#               'ehull': 0.0,
#               'formation_ene': -0.0482764563,
#               'unitprice': 13.743663564776968},
#              377: {'mat_id': 'mp-601833',
#               'composition': 'Fe13Ge3',
#               'ehull': 0.0,
#               'formation_ene': -0.0802306581,
#               'unitprice': 334.91983453973654},
#              378: {'mat_id': 'mp-601842',
#               'composition': 'Fe9Co7',
#               'ehull': 0.0,
#               'formation_ene': -0.0681737728,
#               'unitprice': 23.653417236237683},
#              379: {'mat_id': 'mp-601848',
#               'composition': 'Fe11Co5',
#               'ehull': 0.0,
#               'formation_ene': -0.0569763134,
#               'unitprice': 17.069360381298576},
#              380: {'mat_id': 'mp-611',
#               'composition': 'Ag3Sn',
#               'ehull': 0.0,
#               'formation_ene': -0.0235234388,
#               'unitprice': 634.7125911236037},
#              381: {'mat_id': 'mp-636368',
#               'composition': 'Ga3Fe',
#               'ehull': 0.0,
#               'formation_ene': -0.2384327631,
#               'unitprice': 543.1147136226314},
#              382: {'mat_id': 'mp-636946',
#               'composition': 'Fe6Ge5',
#               'ehull': 0.0479697259,
#               'formation_ene': -0.0290075941,
#               'unitprice': 754.2969259686081},
#              383: {'mat_id': 'mp-640041',
#               'composition': 'NbZn16',
#               'ehull': 0.0,
#               'formation_ene': -0.0465450465,
#               'unitprice': 6.156416292811305},
#              384: {'mat_id': 'mp-641509',
#               'composition': 'In9Ni13',
#               'ehull': 0.0338137564,
#               'formation_ene': -0.1092640668,
#               'unitprice': 422.07061970681696},
#              385: {'mat_id': 'mp-641526',
#               'composition': 'Fe13Co3',
#               'ehull': 0.0034505538,
#               'formation_ene': -0.0327567884,
#               'unitprice': 10.395214033043016},
#              386: {'mat_id': 'mp-644500',
#               'composition': 'Zn7Mo',
#               'ehull': 0.0129085331,
#               'formation_ene': -0.0252085231,
#               'unitprice': 9.588232040809437},
#              387: {'mat_id': 'mp-646039',
#               'composition': 'In7Cu10',
#               'ehull': 0.0066464793,
#               'formation_ene': 0.0011568356,
#               'unitprice': 406.3134054652108},
#              388: {'mat_id': 'mp-669720',
#               'composition': 'Ni3Sn2',
#               'ehull': 0.0,
#               'formation_ene': -0.2679188835,
#               'unitprice': 26.704316273074458},
#              389: {'mat_id': 'mp-672225',
#               'composition': 'BaZn13',
#               'ehull': 0.0,
#               'formation_ene': -0.1747357236,
#               'unitprice': 2.5756635063131563},
#              390: {'mat_id': 'mp-672227',
#               'composition': 'CaZn13',
#               'ehull': 0.0053182101,
#               'formation_ene': -0.1460763268,
#               'unitprice': 3.035113401716262},
#              391: {'mat_id': 'mp-672707',
#               'composition': 'SrZn13',
#               'ehull': 0.0,
#               'formation_ene': -0.1694484298,
#               'unitprice': 2.782394072740953},
#              392: {'mat_id': 'mp-680383',
#               'composition': 'V17Ge31',
#               'ehull': 0.0,
#               'formation_ene': -0.2042308598,
#               'unitprice': 1150.0062421554114},
#              393: {'mat_id': 'mp-680646',
#               'composition': 'NiSn',
#               'ehull': 0.0083812967,
#               'formation_ene': -0.2410505553,
#               'unitprice': 28.054705024615544},
#              394: {'mat_id': 'mp-683917',
#               'composition': 'In4Cu9',
#               'ehull': 0.0233294568,
#               'formation_ene': 0.0168685685,
#               'unitprice': 325.9724922974717},
#              395: {'mat_id': 'mp-7226',
#               'composition': 'V3Ni',
#               'ehull': 0.0,
#               'formation_ene': -0.1574720838,
#               'unitprice': 272.4748354869814},
#              396: {'mat_id': 'mp-7250',
#               'composition': 'Nb6Co7',
#               'ehull': 0.0,
#               'formation_ene': -0.1635495527,
#               'unitprice': 46.50508961770295},
#              397: {'mat_id': 'mp-753',
#               'composition': 'ZnSb',
#               'ehull': 0.0,
#               'formation_ene': -0.0281387281,
#               'unitprice': 10.33287798984248},
#              398: {'mat_id': 'mp-755',
#               'composition': 'CoSb2',
#               'ehull': 0.0024733958,
#               'formation_ene': -0.1765378817,
#               'unitprice': 21.68694964283219},
#              399: {'mat_id': 'mp-7558',
#               'composition': 'TaGe2',
#               'ehull': 0.0,
#               'formation_ene': -0.2256514911,
#               'unitprice': 729.9215977945231},
#              400: {'mat_id': 'mp-784',
#               'composition': 'KZn13',
#               'ehull': 0.0,
#               'formation_ene': -0.0669955366,
#               'unitprice': 46.779457160821416},
#              401: {'mat_id': 'mp-784630',
#               'composition': 'Ni2Mo',
#               'ehull': 0.0061546489,
#               'formation_ene': -0.0767569333,
#               'unitprice': 28.763264536741563},
#              402: {'mat_id': 'mp-784631',
#               'composition': 'CrNi2',
#               'ehull': 0.0,
#               'formation_ene': -0.0186619033,
#               'unitprice': 15.735020182695893},
#              403: {'mat_id': 'mp-810',
#               'composition': 'NiSb',
#               'ehull': 0.0,
#               'formation_ene': -0.2708554525,
#               'unitprice': 15.678875401710249},
#              404: {'mat_id': 'mp-862679',
#               'composition': 'TaZn2',
#               'ehull': 0.0,
#               'formation_ene': -0.0894705012,
#               'unitprice': 89.34186231743915},
#              405: {'mat_id': 'mp-864984',
#               'composition': 'MnV3',
#               'ehull': 0.0,
#               'formation_ene': -0.1478045699,
#               'unitprice': 272.7066968336377},
#              406: {'mat_id': 'mp-950',
#               'composition': 'NaZn13',
#               'ehull': 0.0,
#               'formation_ene': -0.0546934511,
#               'unitprice': 9.453158426031008},
#              407: {'mat_id': 'mp-953',
#               'composition': 'NbZn3',
#               'ehull': 0.0,
#               'formation_ene': -0.1640308538,
#               'unitprice': 15.587497921384516},
#              408: {'mat_id': 'mp-971669',
#               'composition': 'FeSb3',
#               'ehull': 0.0,
#               'formation_ene': -0.0231923719,
#               'unitprice': 12.430945312293503},
#              409: {'mat_id': 'mp-971720',
#               'composition': 'ZnGa3',
#               'ehull': 0.0359487163,
#               'formation_ene': 0.0359487163,
#               'unitprice': 524.8568641717677},
#              410: {'mat_id': 'mp-971804',
#               'composition': 'ZnNi3',
#               'ehull': 0.0126181325,
#               'formation_ene': -0.1148984563,
#               'unitprice': 14.318023689146212},
#              411: {'mat_id': 'mp-971832',
#               'composition': 'ZnIn3',
#               'ehull': 0.0982586287,
#               'formation_ene': 0.0982586287,
#               'unitprice': 605.5920149808244},
#              412: {'mat_id': 'mp-971919',
#               'composition': 'ZnSn3',
#               'ehull': 0.0997404287,
#               'formation_ene': 0.0997404287,
#               'unitprice': 28.13312226876737},
#              413: {'mat_id': 'mp-972048',
#               'composition': 'Zn6Mo',
#               'ehull': 0.0,
#               'formation_ene': -0.04356235,
#               'unitprice': 10.477326907739982},
#              414: {'mat_id': 'mp-972071',
#               'composition': 'V3Mo',
#               'ehull': 0.0,
#               'formation_ene': -0.0682152325,
#               'unitprice': 243.22023508608746},
#              415: {'mat_id': 'mp-972692',
#               'composition': 'SnPb',
#               'ehull': 0.045975585,
#               'formation_ene': 0.045975585,
#               'unitprice': 13.407337681740666},
#              416: {'mat_id': 'mp-978882',
#               'composition': 'SnBi3',
#               'ehull': 0.09985976,
#               'formation_ene': 0.09985976,
#               'unitprice': 26.49501329321433},
#              417: {'mat_id': 'mp-979289',
#               'composition': 'TaW3',
#               'ehull': 0.0,
#               'formation_ene': -0.09023669,
#               'unitprice': 64.08000332246652},
#              418: {'mat_id': 'mp-981200',
#               'composition': 'Zn3Cd',
#               'ehull': 0.0673983637,
#               'formation_ene': 0.0673983637,
#               'unitprice': 2.8695955888545184},
#              419: {'mat_id': 'mp-983237',
#               'composition': 'Ga3Bi',
#               'ehull': 0.0716040075,
#               'formation_ene': 0.0716040075,
#               'unitprice': 356.8349321575041},
#              420: {'mat_id': 'mp-984351',
#               'composition': 'CuAg3',
#               'ehull': 0.0856875975,
#               'formation_ene': 0.0856875975,
#               'unitprice': 716.6703297272805},
#              421: {'mat_id': 'mp-985475',
#               'composition': 'Fe3Mo',
#               'ehull': 0.0866950575,
#               'formation_ene': 0.0866950575,
#               'unitprice': 15.162134474705377},
#              422: {'mat_id': 'mp-985556',
#               'composition': 'CdNi',
#               'ehull': 0.0,
#               'formation_ene': -0.0203907646,
#               'unitprice': 8.15363038619568},
#              423: {'mat_id': 'mp-999189',
#               'composition': 'Fe3Ni',
#               'ehull': 0.0833200075,
#               'formation_ene': 0.0494485675,
#               'unitprice': 4.966609915915863},
#              424: {'mat_id': 'mp-999389',
#               'composition': 'NbFe3',
#               'ehull': 0.0471338494,
#               'formation_ene': -0.0502349925,
#               'unitprice': 15.218126843169083},
#              425: {'mat_id': 'mp-999395',
#               'composition': 'Nb3Fe',
#               'ehull': 0.084836684,
#               'formation_ene': 0.0305542825,
#               'unitprice': 35.25789696334461}})

# %%
ele_remove_list=['As', 'Be', 'Cd', 'Cr', 'Pb', 'Hg']
MO_selected = notincludeElement(MO_noDup, ele_remove_list)
# BM_selected = rmDupDict(BM_selected)
print (len(MO_selected))

BM_selected = notincludeElement(BM_noDup, ele_remove_list)
# BM_selected = rmDupDict(BM_selected)
print (len(BM_selected))

TM_selected = notincludeElement(TM_noDup, ele_remove_list)
# BM_selected = rmDupDict(BM_selected)
print (len(TM_selected))

# ele_keep_list = ['Ag', 'Cu', 'Fe', 'Ni']
# ele_keep_list = ['Ni']
# BM_selected = includeElement(BM_selected, ele_keep_list)
# # BM_selected = rmDupDict(BM_selected)
# print (len(BM_selected))
# BM_selected

# with open('BM_selected_Ni.json', 'w') as op_BM:
#     json.dump(BM_selected, op_BM)
# Out:
# 33
# 357
# 285

# %%
# MO_compounds = get_compounds(MO_filter3)
# MO_pairs = get_pairs(MO_compounds)
# eleList = getMOElements(MO_pairs)

MO_compounds = get_compounds(MO_filter3)
MO_comp_nodup = rmDup(MO_compounds)
BM_compounds = get_compounds(BM_filter3)
BM_comp_nodup = rmDup(BM_compounds)
TM_compounds = get_compounds(TM_filter3)
TM_comp_nodup = rmDup(TM_compounds)
print (len(MO_comp_nodup), len(BM_comp_nodup), len(TM_comp_nodup))
# BM_pairs = get_pairs(BM_compounds)
# BM_pairs = rmDupPair(BM_pairs)
# #printTable(BM_pairs)

# TM_compounds = get_compounds(TM_filter3)
# TM_pairs3 = get_pairs(TM_compounds)
# TM_pairs = tuple3to2(TM_pairs3)
# TM_pairs = rmDupPair(TM_pairs)
# printTable(TM_pairs)
